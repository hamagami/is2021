# %% [markdown]
# <a href="https://colab.research.google.com/github/hamagami/is2021/blob/main/Logistic_Regression3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ## Logistic regression

# %%
import math
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris

# %% [markdown]
# Import dataset (IRIS)

# %%
iris = load_iris()
iris.data=iris.data[:,2:4]

iris_data = np.zeros([iris.data.shape[0], iris.data.shape[1] + 1])
for i in range(iris.data.shape[0]):
    for j in range(iris.data.shape[1]):
        iris_data[i, j] = iris.data[i, j]
    iris_data[i, iris.data.shape[1]] = 1
iris_data = iris_data[50:]

iris_target = iris.target[50:] - 1
iris.feature_names = iris.feature_names[2:4]

# %%
#index
index = np.arange(len(iris_data))
np.random.shuffle(index)
 
iris_train_data =  iris_data[index[:70]]
iris_train_target = iris_target[index[:70]]

# %%
# average
iris_mu = [sum(iris_train_data[:, row]) / len(iris_train_data[:, row]) for row in range(iris_train_data.shape[1])]
 
# distribution
iris_sigma = [math.sqrt(sum((iris_train_data[:, row] - iris_mu[row]) ** 2  / len(iris_train_data[:, row]))) for row in range(iris_train_data.shape[1])]
 
# reguralization
for i in range(iris_train_data.shape[0]):
    for j in range(iris_train_data.shape[1] - 1):
        iris_train_data[i, j] = (iris_train_data[i, j] - iris_mu[j]) / iris_sigma[j]

# %%
#initialization
w = np.random.random(len(iris.feature_names) + 1)
x = np.linspace(2, -2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(y, x)
t= np.c_[X.ravel(),Y.ravel()]
t=np.insert(t,2,1, axis=1)

# %%
xp= iris_train_data[iris_train_target==0][:,0]
yp= iris_train_data[iris_train_target==0][:,1]
plt.scatter(xp,yp)
xp= iris_train_data[iris_train_target==1][:,0]
yp= iris_train_data[iris_train_target==1][:,1]
plt.scatter(xp,yp)
plt.show()

# %% [markdown]
# Logistic Regression

# %%
alpha=0.01
eta=0.01
for i in range(3000):
    y_hat = 1 / (1 + np.exp(-np.dot(iris_train_data, w)))
    w = w +  alpha * ((np.dot((y_hat - iris_train_target), iris_train_data) - (eta * w)) / iris_train_data.shape[0])
    
    if i%100==0:
        zp= (1/ (1 + np.exp(-np.dot(t, w))))
        xp= iris_train_data[iris_train_target==0][:,0]
        yp= iris_train_data[iris_train_target==0][:,1]
        plt.scatter(xp,yp)
        xp= iris_train_data[iris_train_target==1][:,0]
        yp= iris_train_data[iris_train_target==1][:,1]
        plt.scatter(xp,yp)
        plt.imshow(zp.reshape(100,100),extent=[-2.5, 2.5, -2.5, 2.5] )    
        print("iteration=",i)
        plt.show()
# Out:
# iteration= 0
# iteration= 100
# iteration= 200
# iteration= 300
# iteration= 400
# iteration= 500
# iteration= 600
# iteration= 700
# iteration= 800
# iteration= 900
# iteration= 1000
# iteration= 1100
# iteration= 1200
# iteration= 1300
# iteration= 1400
# iteration= 1500
# iteration= 1600
# iteration= 1700
# iteration= 1800
# iteration= 1900
# iteration= 2000
# iteration= 2100
# iteration= 2200
# iteration= 2300
# iteration= 2400
# iteration= 2500
# iteration= 2600
# iteration= 2700
# iteration= 2800
# iteration= 2900

# %%
w
# Out:
# array([-21.59436889, -21.8519165 ,  -3.49290724])
